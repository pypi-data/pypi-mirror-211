# %% [markdown]
# # Import Modules
#
# We will need some basic packages, but will also need to import different AutoRA theorists. Here, we will import our three theorists: Bayesian Machine Scientist, Bayesian Symbolic Regression, and Differentiable Architecture Search.
#
# Note that we are currently re-structuring the AutoRA package so that all experimentalists and theorists are their own sub-package. As such, once this is complete for the theorists, these imports should be modified to conform to the new structure.

# %%
import numpy as np
import matplotlib.pyplot as plt
from autora.theorist.bms import BMSRegressor; BMSRegressor()
from autora.theorist.bsr import BSRRegressor; BSRRegressor()
from autora.theorist.darts import DARTSRegressor; DARTSRegressor()
from autora.experimentalist.sampler.model_disagreement import model_disagreement_sampler

# %% [markdown]
# # Define Meta-Space
#
# We will here define X values of interest as well as a ground truth model to derive y values.

# %%
#Define meta-parameters
X = np.linspace(start=-3, stop=6, num=10).reshape(-1, 1)

#Define ground truth model
def ground_truth(xs):
    y = (xs ** 2.0)
    y[xs < 0] = 0
    return y

# %% [markdown]
# # Plot the Data
#
# Let's plot the data to see what we are working with.

# %%
plt.plot(X, ground_truth(X), 'o')
plt.show()

# %% [markdown]
# # Define and Fit Theorists
#
# Next, we initialize each theorist and then train them on the data.
#
# Note that this can take quite some time, especially for the BSR Theorist.

# %%
# %%capture

#Initiate theorists
bms_theorist = BMSRegressor()
bsr_theorist = BSRRegressor()
darts_theorist = DARTSRegressor()

#Fit theorists
bms_theorist.fit(X,ground_truth(X))
bsr_theorist.fit(X,ground_truth(X))
darts_theorist.fit(X,ground_truth(X))
# Out:
# INFO:autora.theorist.bms.regressor:BMS fitting started
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 7
#       4 darts_theorist = DARTSRegressor()
#       6 #Fit theorists
# ----> 7 bms_theorist.fit(X,ground_truth(X))
#       8 bsr_theorist.fit(X,ground_truth(X))
#       9 darts_theorist.fit(X,ground_truth(X))
#
# File c:\Users\cwill\GitHub\virtualEnvs\autoraEnv\lib\site-packages\autora\theorist\bms\regressor.py:133, in BMSRegressor.fit(self, X, y, num_param, root, custom_ops, seed)
#     120     self.add_primitive(root)
#     121 self.pms = Parallel(
#     122     Ts=self.ts,
#     123     variables=self.variables,
#    (...)
#     131     seed=seed,
#     132 )
# --> 133 self.model_, self.loss_, self.cache_ = utils.run(self.pms, self.epochs)
#     134 self.models_ = list(self.pms.trees.values())
#     136 _logger.info("BMS fitting finished")
#
# File c:\Users\cwill\GitHub\virtualEnvs\autoraEnv\lib\site-packages\autora\theorist\bms\utils.py:35, in run(pms, num_steps, thinning)
#      33 desc_len, model, model_len = [], pms.t1, np.inf
#      34 for n in tqdm(range(num_steps)):
# ---> 35     pms.mcmc_step()
#      36     pms.tree_swap()
#      37     if num_steps % thinning == 0:  # sample less often if we thin more
#
# File c:\Users\cwill\GitHub\virtualEnvs\autoraEnv\lib\site-packages\autora\theorist\bms\parallel.py:102, in Parallel.mcmc_step(self, verbose, p_rr, p_long)
#      99     p_rr = 0.0
#     100 for T, tree in list(self.trees.items()):
#     101     # MCMC step
# --> 102     tree.mcmc_step(verbose=verbose, p_rr=p_rr, p_long=p_long)
#     103 self.t1 = self.trees["1.0"]
#
# File c:\Users\cwill\GitHub\virtualEnvs\autoraEnv\lib\site-packages\autora\theorist\bms\mcmc.py:1251, in Tree.mcmc_step(self, verbose, p_rr, p_long)
#    1249 sf = len(self.et_space[ofin])
#    1250 # Probability of acceptance
# -> 1251 dE, dEB, dEP, par_valuesNew, nif, nfi = self.dE_et(
#    1252     target, new, verbose=verbose
#    1253 )
#    1254 try:
#    1255     paccept = (
#    1256         float(nif) * omegai * sf * np.exp(-dEB / self.BT - dEP / self.PT)
#    1257     ) / (float(nfi) * omegaf * si)
#
# File c:\Users\cwill\GitHub\virtualEnvs\autoraEnv\lib\site-packages\autora\theorist\bms\mcmc.py:886, in Tree.dE_et(self, target, new, verbose)
#     884 old = [target.value, [o.value for o in target.offspring]]
#     885 # replace
# --> 886 added = self.et_replace(target, new, update_gof=True, verbose=verbose)
#     887 bicNew = self.bic
#     888 par_valuesNew = deepcopy(self.par_values)
#
# File c:\Users\cwill\GitHub\virtualEnvs\autoraEnv\lib\site-packages\autora\theorist\bms\mcmc.py:596, in Tree.et_replace(self, target, new, update_gof, verbose)
#     594 if update_gof:
#     595     self.sse = self.get_sse(verbose=verbose)
# --> 596     self.bic = self.get_bic(verbose=verbose)
#     597 # Done
#     598 return added
#
# File c:\Users\cwill\GitHub\virtualEnvs\autoraEnv\lib\site-packages\autora\theorist\bms\mcmc.py:722, in Tree.get_bic(self, reset, fit, verbose)
#     720     return 0
#     721 # Get the sum of squared errors (fitting, if required)
# --> 722 sse = self.get_sse(fit=fit, verbose=verbose)
#     723 # Calculate the BIC
#     724 parameters = set([p.value for p in self.ets[0] if p.value in self.parameters])
#
# File c:\Users\cwill\GitHub\virtualEnvs\autoraEnv\lib\site-packages\autora\theorist\bms\mcmc.py:628, in Tree.get_sse(self, fit, verbose)
#     619 dic: dict = dict(
#     620     {
#     621         "fac": scipy.special.factorial,
#    (...)
#     625     **self.custom_ops
#     626 )
#     627 try:
# --> 628     flam = lambdify(
#     629         variables + parameters,
#     630         ex,
#     631         [
#     632             "numpy",
#     633             dic,
#     634         ],
#     635     )
#     636 except (SyntaxError, KeyError):
#     637     self.sse = dict([(ds, np.inf) for ds in self.x])
#
# File c:\Users\cwill\GitHub\virtualEnvs\autoraEnv\lib\site-packages\sympy\utilities\lambdify.py:830, in lambdify(args, expr, modules, printer, use_imps, dummify, cse, docstring_limit)
#     828                 for k in m:
#     829                     user_functions[k] = k
# --> 830         printer = Printer({'fully_qualified_modules': False, 'inline': True,
#     831                            'allow_unknown_functions': True,
#     832                            'user_functions': user_functions})
#     834     if isinstance(args, set):
#     835         sympy_deprecation_warning(
#     836             """
#     837 Passing the function arguments to lambdify() as a set is deprecated. This
#    (...)
#     842             active_deprecations_target="deprecated-lambdify-arguments-set",
#     843                 )
#
# File c:\Users\cwill\GitHub\virtualEnvs\autoraEnv\lib\site-packages\sympy\printing\numpy.py:56, in NumPyPrinter.__init__(self, settings)
#      52 self.printmethod = "_{}code".format(self._module)
#      54 self._kf = {**PythonCodePrinter._kf, **self._kf}
# ---> 56 super().__init__(settings=settings)
#
# File c:\Users\cwill\GitHub\virtualEnvs\autoraEnv\lib\site-packages\sympy\printing\pycode.py:99, in AbstractPythonCodePrinter.__init__(self, settings)
#      88 _operators = {'and': 'and', 'or': 'or', 'not': 'not'}
#      89 _default_settings = dict(
#      90     CodePrinter._default_settings,
#      91     user_functions={},
#    (...)
#      96     standard='python3',
#      97 )
# ---> 99 def __init__(self, settings=None):
#     100     super().__init__(settings)
#     102     # Python standard handler
#
# KeyboardInterrupt:

# %% [markdown]
# # Plot Theorists on Data
#
# We can then plot each theorist to see how well it recovered the data.

# %%
plt.plot(X, ground_truth(X), 'o')
plt.plot(X, bms_theorist.predict(X), alpha = .5, label = 'BMS Theorist')
plt.plot(X, bsr_theorist.predict(X), alpha = .5, label = 'BSR Theorist')
plt.plot(X, darts_theorist.predict(X), alpha = .5, label = 'DARTS Theorist')
plt.legend()
plt.show()

# %% [markdown]
# # Plot Model Disagreements
#
# We can also plot the disagreement between each pair of theorists. The grey dashed lines represent the degree of disagreement for each datapoint. Computationally the Model Disagreement Sampler takes the square of these numbers to determine where disagreement is largest.

# %%
fig, ax = plt.subplots(1,3, figsize=[12,4])

def plot_disagreement(X, model_a, model_b, plot_index, labels):
    ax[plot_index].plot(X, model_a.predict(X), alpha = .5, label = labels[0]) #Plot model a
    ax[plot_index].plot(X, model_b.predict(X), alpha = .5, label = labels[1]) #Plot model b
    for xi, _ in enumerate(X):
        ax[plot_index].plot([X[xi],X[xi]], [model_a.predict(X)[xi], model_b.predict(X)[xi]], alpha = .7, c = 'grey', linestyle = '--') #Plot disagreement
    ax[plot_index].legend()
        
plot_disagreement(X, bms_theorist, bsr_theorist, 0, ['BSM Theorist', 'BSR Theorist'])
plot_disagreement(X, bms_theorist, darts_theorist, 1, ['BSM Theorist', 'DARTS Theorist'])
plot_disagreement(X, bsr_theorist, darts_theorist, 2, ['BSR Theorist', 'BSM Theorist'])
plt.show()

# %% [markdown]
# # Run and Report Model Disagreement Samples
#
# Now we will get a proposal from the sampler as to which datapoints to investigate next. We will retrieve 5 new datapoints in this example.

# %%
sampler_proposal = model_disagreement_sampler(X, [bms_theorist, bsr_theorist, darts_theorist], 5)

print('New datapoints:\n' + str(sampler_proposal))
# Out:
# New datapoints:
# [[-3.]
#  [ 4.]
#  [ 5.]
#  [ 6.]
#  [ 1.]]

# %% [markdown]
# # Plot New Datapoints With Old
#
# We can then plot our new datapoints with our previous ones to demonstrate our new dataset of investigation for then next cycle.

# %%
plt.plot(X, ground_truth(X), 'o', alpha = .5, label = 'Original Datapoints')
plt.plot(sampler_proposal, ground_truth(sampler_proposal), 'o', alpha = .5, label = 'Proposed Datapoints')
plt.legend()
plt.show()
