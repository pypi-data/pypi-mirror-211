# %% [markdown]
# # ScienceIO API Demo
#
# In this demo, we'll:
# - Log in with our user account
# - Make our first request
# - Put the request in a pandas dataframe and analyze

# %%
import pandas as pd
import yaml
from IPython.display import display, JSON

from analytics import *
from scienceio import ScienceIO

# %% [markdown]
# ## Initialize client

# %%
scio = ScienceIO()

# %% [markdown]
# If the account already exists (based on the login), you will be notified and can proceed to logging in.

# %% [markdown]
# ## Make a request to the API

# %%
query_text = (
    """
    The patient is a 21-day-old Caucasian male here for 2 days of congestion - 
    mom has been suctioning yellow discharge from the patient's nares, plus she has noticed 
    some mild problems with his breathing while feeding (but negative for any perioral cyanosis or retractions). 
    One day ago, mom also noticed a tactile temperature and gave the patient Tylenol. Baby also has 
    had some decreased p.o. intake. His normal breast-feeding is down from 20 minutes q.2h. 
    to 5 to 10 minutes secondary to his respiratory congestion. He sleeps well, but has been more tired 
    and has been fussy over the past 2 days. The parents noticed no improvement with albuterol treatments given
    in the ER. His urine output has also decreased; normally he has 8 to 10 wet and 5 dirty diapers per 24 hours,
    now he has down to 4 wet diapers per 24 hours. Mom denies any diarrhea. His bowel movements are yellow colored and soft in nature.
    """
)


# Make a request
response_query = scio.annotate(text=query_text)
# Out:
# <class 'str'>

# %%
# We can pass `spans` directly to a dataframe
df = pd.DataFrame(response_query['annotations'])
display(df)
report(df)
# Out:
#     annotation_id     concept_id           concept_name          concept_type  \
# 0               1  UMLS:C0086418           Homo sapiens     species_&_viruses
# 1               2  UMLS:C0007457         Caucasoid Race               context
# 2               3  UMLS:C0086582                  Males  anatomy_&_physiology
# 3               4  UMLS:C0700148             Congestion    medical_conditions
# 4               5  UMLS:C0221205           Yellow color               context
# 5               6  UMLS:C0030685      Patient Discharge    medical_procedures
# 6               7  UMLS:C0086418           Homo sapiens     species_&_viruses
# 7               8  UMLS:C0595944         Anterior nares  anatomy_&_physiology
# 8               9  UMLS:C0010520               Cyanosis    medical_conditions
# 9              10  UMLS:C1704938        FBXW7 wt Allele              genetics
# 10             11  UMLS:C0039476            Temperature               context
# 11             12  UMLS:C0086418           Homo sapiens     species_&_viruses
# 12             13     CHEMBL:112            Paracetamol     chemicals_&_drugs
# 13             14  UMLS:C0021270                 Infant               context
# 14             15  UMLS:C0567498          Breast normal    medical_conditions
# 15             16      CID:24523              Deuterium     chemicals_&_drugs
# 16             17  UMLS:C0700148             Congestion    medical_conditions
# 17             18  UMLS:C4284302         EHD1 wt Allele              genetics
# 18             19  UMLS:C0030551                 parent               context
# 19             20     CHEMBL:714             Salbutamol     chemicals_&_drugs
# 20             21  UMLS:C0087111  Therapeutic procedure    medical_procedures
# 21             22  UMLS:C1287298   Urine volume finding    medical_conditions
# 22             23  UMLS:C0011135             Defecation  anatomy_&_physiology
# 23             24  UMLS:C0221205           Yellow color               context
#
#     pos_end  pos_start  score_id  score_type               text
# 0        13          6  0.999990    0.999998            patient
# 1        39         30  0.999910    0.999870          Caucasian
# 2        44         40  0.999974    0.999978               male
# 3        74         64  0.999889    0.999847         congestion
# 4       109        103  0.999917    0.999898             yellow
# 5       119        110  0.996726    0.995705          discharge
# 6       136        129  0.999974    0.999986            patient
# 7       144        139  0.999976    0.999790              nares
# 8       260        243  0.999220    0.998834  perioral cyanosis
# 9       291        288  0.999992    0.999987                ago
# 10      331        320  0.905596    0.893862        temperature
# 11      352        345  0.999937    0.999977            patient
# 12      360        353  0.977127    0.999146            Tylenol
# 13      366        362  0.999860    0.999823               Baby
# 14      427        414  0.999271    0.999939      normal breast
# 15      464        462  0.999960    0.999842                 2h
# 16      526        516  0.999881    0.986120         congestion
# 17      602        598  0.998674    0.997825               past
# 18      622        615  0.999914    0.999847            parents
# 19      660        651  0.999870    0.999937          albuterol
# 20      671        661  0.999989    0.999997         treatments
# 21      706        694  0.999218    0.999941       urine output
# 22      881        866  0.999310    0.999707    bowel movements
# 23      892        886  0.999877    0.999939             yellow
# Found 24 mentions of healthcare information (20 unique).
# Found 20 unique concepts, spanning 7 categories.

# %%
# This is the text we'll send to the API
query_text = (
    """
    The COVID-19 pandemic has shown a markedly low proportion of 
    cases among children. Age disparities in observed COVID-19 cases could be 
    explained by children having lower susceptibility to infection, lower 
    propensity to show clinical symptoms or both. COVID-19 has shown to induce
    Kawasaki syndrome in some children. Kawasaki (KD), or Mucocutaneous Lymph Node Syndrome
    as it is often called, is an acute illness that affects mostly children 6 months to 5 years 
    old—median age in the KD cohort was 25 months—and features inflammation of small and medium 
    blood vessels. Although the cause of KD is unknown, it is believed to occur in genetically 
    predisposed children after exposure to an environmental trigger such as an infection.
    """
)

# Make a request
response_query = scio.annotate(text=query_text)
# Out:
# <class 'str'>

# %%
# We can pass `spans` directly to a dataframe
df = pd.DataFrame(response_query['annotations'])
display(df)
# Out:
#     annotation_id     concept_id                       concept_name  \
# 0               1  UMLS:C5203670                           COVID-19
# 1               2  UMLS:C1615608                          Pandemics
# 2               3  UMLS:C0008059                              Child
# 3               4  UMLS:C0001779                                Age
# 4               5  UMLS:C5203670                           COVID-19
# 5               6  UMLS:C0008059                              Child
# 6               7  UMLS:C0009450              Communicable Diseases
# 7               8  UMLS:C5203670                           COVID-19
# 8               9  UMLS:C0026691  Mucocutaneous Lymph Node Syndrome
# 9              10  UMLS:C0008059                              Child
# 10             11  UMLS:C0026691  Mucocutaneous Lymph Node Syndrome
# 11             12  UMLS:C0026691  Mucocutaneous Lymph Node Syndrome
# 12             13  UMLS:C0008679                    Chronic disease
# 13             14  UMLS:C0086418                       Homo sapiens
# 14             15  UMLS:C0001779                                Age
# 15             16  UMLS:C0026691  Mucocutaneous Lymph Node Syndrome
# 16             17  UMLS:C0009247                     Cohort Studies
# 17             18  UMLS:C1521970                    Characteristics
# 18             19  UMLS:C0021368                       Inflammation
# 19             20  UMLS:C0005847                       Blood Vessel
# 20             21  UMLS:C0015127                   Etiology aspects
# 21             22  UMLS:C0026691  Mucocutaneous Lymph Node Syndrome
# 22             23  UMLS:C1549625             Unknown - Ethnic Group
# 23             24  UMLS:C0008059                              Child
# 24             25  UMLS:C0014406                        Environment
# 25             26  UMLS:C0009450              Communicable Diseases
#
#             concept_type  pos_end  pos_start  score_id  score_type  \
# 0     medical_conditions       14          6  0.999316    0.999914
# 1   anatomy_&_physiology       23         15  0.999836    0.998517
# 2                context       85         77  0.581539    0.505265
# 3   anatomy_&_physiology       90         87  0.999856    0.999865
# 4     medical_conditions      123        115  0.998266    0.999884
# 5                context      162        154  0.549657    0.500652
# 6     medical_conditions      203        194  0.922211    0.999919
# 7     medical_conditions      267        259  0.999292    0.999893
# 8     medical_conditions      306        289  0.999932    0.999624
# 9      species_&_viruses      323        315  0.539449    0.527990
# 10    medical_conditions      337        335  0.999357    0.999890
# 11    medical_conditions      376        343  0.692145    0.997312
# 12    medical_conditions      420        413  0.999843    0.999546
# 13     species_&_viruses      449        441  0.548630    0.587823
# 14  anatomy_&_physiology      486        483  0.999968    0.999983
# 15    medical_conditions      496        494  0.995664    0.999884
# 16               context      503        497  0.999917    0.999965
# 17               context      530        522  0.999962    0.999926
# 18    medical_conditions      543        531  0.999757    0.999983
# 19  anatomy_&_physiology      579        566  0.999773    0.999878
# 20               context      599        594  0.999792    0.999965
# 21    medical_conditions      605        603  0.999664    0.999860
# 22               context      616        609  0.999457    0.999878
# 23     species_&_viruses      679        671  0.508559    0.544517
# 24               context      714        701  0.999917    0.999811
# 25    medical_conditions      743        734  0.884321    0.999933
#
#                                  text
# 0                            COVID-19
# 1                            pandemic
# 2                            children
# 3                                 Age
# 4                            COVID-19
# 5                            children
# 6                           infection
# 7                            COVID-19
# 8                   Kawasaki syndrome
# 9                            children
# 10                                 KD
# 11  Mucocutaneous Lymph Node Syndrome
# 12                            illness
# 13                           children
# 14                                age
# 15                                 KD
# 16                             cohort
# 17                           features
# 18                       inflammation
# 19                      blood vessels
# 20                              cause
# 21                                 KD
# 22                            unknown
# 23                           children
# 24                      environmental
# 25                          infection

# %% [markdown]
# ## Viewing the results

# %%
report(df)
# Out:
# Found 26 mentions of healthcare information (17 unique).
# Found 15 unique concepts, spanning 4 categories.

# %%
# top mentions
get_top(df, "text")
# Out:
#             text  mentions
# 0       children         5
# 1             KD         3
# 2       COVID-19         3
# 3      infection         2
# 4  environmental         1
# 5       pandemic         1
# 6   inflammation         1
# 7        illness         1
# 8       features         1
# 9            Age         1

# %%
# top concepts
get_top(df, "concept_name")
# Out:
#                         concept_name  mentions
# 0  Mucocutaneous Lymph Node Syndrome         5
# 1                              Child         4
# 2                           COVID-19         3
# 3                                Age         2
# 4              Communicable Diseases         2
# 5                       Blood Vessel         1
# 6                    Characteristics         1
# 7                    Chronic disease         1
# 8                     Cohort Studies         1
# 9                        Environment         1

# %%
# top concept types
get_top(df, "concept_type")
# Out:
#            concept_type  mentions
# 0    medical_conditions        12
# 1               context         7
# 2  anatomy_&_physiology         4
# 3     species_&_viruses         3
